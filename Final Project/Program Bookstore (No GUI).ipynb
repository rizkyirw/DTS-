# %%
class Bookstore:
    def __init__(self, jdl, no_id):
        self.judul = str(jdl);
        self.id = str(no_id);

    def getJudul(self):
        return self.judul;

    def getId(self):
        return self.id;

    def setJudul(self, jdl):
        self.judul = jdl;

    def setId(self, no_induk):
        self.id = no_id;

DftrBook = {};
loop = True;

print("===================================");
print("=         Daftar Buku             =");
print("===================================");
print("= # MENU                          =");
print("= 1. Tambah Buku                  =");
print("= 2. Hapus Buku                   =");
print("= 3. Tampilkan Semua Buku         =");
print("= 4. Cari Buku                    =");
print("= 5. Edit Judul Buku              =");
print("= 6. Edit Id Buku                 =");
print("= 7. Jumlah Total Buku            =");
print("= 0. Keluar                       =");
print("===================================");

while(loop):
    print("\n\n");
    menu = int(input("Masukan menu : "));

    if menu == 1:
        judul = str(input("Masukan judul : "));
        no_id = str(input("Masukan Id : "));
        krj = Bookstore(judul, no_id);
        DftrBook[no_id] = krj;

    elif menu == 2:
        no_id = str(input("Masukan Id : "));
        if(no_id in DftrBook):
            del DftrBook[no_id];
        else:
            print("Data tidak ditemukan!!!");

    elif menu == 3:
        for i in DftrBook:
            print("Judul :", DftrBook[i].getJudul());
            print("No Id :", DftrBook[i].getId());

    elif menu == 4:
        no_id = str(input("Masukan Id : "));
        if(no_id in DftrBook):
            print("Judul :", DftrBook[i].getJudul());
            print("No Id :", DftrBook[i].getId());
        else:
            print("Data tidak ditemukan!!!");

    elif menu == 5:
        no_id = str(input("Masukan Id : "));
        if(no_id in DftrBook):
            judulBaru = str(input("Masukan Judul Baru : "));
            DftrBook[no_id].setJudul(judulBaru);
        else:
            print("Data tidak ditemukan!!!");

    elif menu == 6:
        no_id = str(input("Masukan Id : "));
        if(no_id in DftrBook):
            IdBaru = str(input("Masukan Id Baru : "));
            DftrBook[no_id].setId(IdBaru);
            krj = DftrBook[no_id];
            DftrBook[IdBaru] = krj;
            del DftrBook[no_id];
        else:
            print("Data tidak ditemukan!!!");

    elif menu == 7:
        print("Jumlah Buku Yang Dimasukan : ", len(DftrBook));

    elif menu == 0:
        loop = False;
else:
    print("XXXX Error XXXX");
# Out:
# ...
# =         Daftar Buku             =
# ...
# = # MENU                          =
# = 1. Tambah Buku                  =
# = 2. Hapus Buku                   =
# = 3. Tampilkan Semua Buku         =
# = 4. Cari Buku                    =
# = 5. Edit Judul Buku              =
# = 6. Edit Id Buku                 =
# = 7. Jumlah Total Buku            =
# = 0. Keluar                       =
# ...
#
#
#
# Masukan menu : 1
# Masukan judul : One Piece
# Masukan Id : A111
#
#
#
# Masukan menu : 1
# Masukan judul : Bleach
# Masukan Id : A122
#
#
#
# Masukan menu : 3
# Judul : One Piece
# No Id : A111
# Judul : Bleach
# No Id : A122
#
#
#
# Masukan menu : 2
# Masukan Id : A122
#
#
#
# Masukan menu : 3
# Judul : One Piece
# No Id : A111
#
#
#
# Masukan menu : 0
# XXXX Error XXXX
